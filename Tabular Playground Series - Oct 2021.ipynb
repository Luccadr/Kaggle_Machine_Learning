# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

from lightgbm import LGBMClassifier
from skopt import dummy_minimize
from skopt import gp_minimize



from sklearn import impute
from sklearn import metrics
from sklearn import ensemble
from sklearn import linear_model
from sklearn import decomposition
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import optuna


import time
import random
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## reduce_memory_usage

# %%
def reduce_memory_usage(df, verbose=True):
    numerics = ["int8", "int16", "int32", "int64", "float16", "float32", "float64"]
    start_mem = df.memory_usage().sum() / 1024 ** 2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if (
                    c_min > np.finfo(np.float16).min
                    and c_max < np.finfo(np.float16).max
                ):
                    df[col] = df[col].astype(np.float16)
                elif (
                    c_min > np.finfo(np.float32).min
                    and c_max < np.finfo(np.float32).max
                ):
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024 ** 2
    if verbose:
        print(
            "Mem. usage decreased to {:.2f} Mb ({:.1f}% reduction)".format(
                end_mem, 100 * (start_mem - end_mem) / start_mem
            )
        )
    return df

# %% [markdown]
# # Looking Data

# %%
test = pd.read_csv("test.csv").drop(columns = ["id"])
test = reduce_memory_usage(test)
# Out:
# Mem. usage decreased to 250.34 Mb (77.0% reduction)

# %%
train = pd.read_csv("train.csv").drop(columns = ["id"])
train = reduce_memory_usage(train)
# Out:
# Mem. usage decreased to 501.63 Mb (77.0% reduction)

# %%
submission = pd.read_csv("sample_submission.csv")
submission = reduce_memory_usage(submission)
# Out:
# Mem. usage decreased to 2.86 Mb (62.5% reduction)

# %%
target = train['target']

# %%
N_FOLDS = 5

# %% [markdown]
# ## Checking and Preparing Data

# %%
target = 'target'
features = [col for col in train.columns if col != target]

len(features)
# Out:
# 285

# %% [markdown]
# ## Missing Values

# %%
'''train['n_missing'] = train[features].isna().sum(axis=1)
test['n_missing'] = test[features].isna().sum(axis=1)

features.append('n_missing')

modes = train[features].mode().iloc[0]

train[features] = train[features].fillna(modes)
test[features] = test[features].fillna(modes)'''
# Out:
# "train['n_missing'] = train[features].isna().sum(axis=1)\ntest['n_missing'] = test[features].isna().sum(axis=1)\n\nfeatures.append('n_missing')\n\nmodes = train[features].mode().iloc[0]\n\ntrain[features] = train[features].fillna(modes)\ntest[features] = test[features].fillna(modes)"

# %% [markdown]
# ## Scaler the Data
# ### Standardize features by removing the mean and scaling to unit variance

# %%
train['min_row'] = train[features].min(axis=1)
train['max_row'] = train[features].max(axis=1)
train['mean_row'] = train[features].mean(axis=1)
train['std_row'] = train[features].std(axis=1)

test['min_row'] = test[features].min(axis=1)
test['max_row'] = test[features].max(axis=1)
test['mean_row'] = test[features].mean(axis=1)
test['std_row'] = test[features].std(axis=1)

features += ['min_row', 'max_row', 'mean_row', 'std_row']

# %%
bool_cols_train = []
for i, col in enumerate(train.columns):
    if train[col].dtypes == bool:
        bool_cols_train.append(i)

# %%
bool_cols_test = []
for i, col in enumerate(test.columns):
    if train[col].dtypes == bool:
        bool_cols_test.append(i)

# %%
train.iloc[:, bool_cols_train] = train.iloc[:, bool_cols_train].astype(int)
test.iloc[:, bool_cols_test] = test.iloc[:, bool_cols_test].astype(int)

# %%
X_train = train.drop('target', axis=1).copy()
X = train.drop('target', axis=1).copy()
y = train['target'].copy()
X_test = test.copy()

del train
del test

# %% [markdown]
# # Parameters

# %%
N_SPLITS = 5
N_ESTIMATORS = 500
VERBOSE = 50

# %% [markdown]
# ## Random Search

# %%
XRtrain, XRtest, yrtrain, yrtest = train_test_split(X_train, y, train_size = 0.20)

# %%
def model_training(params):
    learning_rate = params[0]
    num_leaves = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    
    print (params, '\n')
    
    model = LGBMClassifier()
    model.fit(XRtrain, yrtrain)
    
    p = model.predict_proba(XRtest)[:,1]
    
    return - roc_auc_score(yrtest,p)



space = [(1e-3, 1e-1, "log-uniform"),
         (2,135),
         (1,100),
         (0.05, 1.0),
         (0.1 , 1.0)]

resultado = dummy_minimize(model_training, space, random_state = 42, verbose = 50, n_calls = 100)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.03918194347141743, 16, 72, 0.6187255599871848, 0.2404167763981929]
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 23.5405
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 2 started. Evaluating function at random point.
# [0.002051110418843398, 76, 75, 0.8728673384861885, 0.6410035105688879]
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 23.2991
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 3 started. Evaluating function at random point.
# [0.026070247583707674, 23, 53, 0.9714143595538948, 0.8491983767203797]
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 25.4977
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 4 started. Evaluating function at random point.
# [0.0026587543983272693, 65, 60, 0.22423428436076215, 0.373818018663584]
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 22.4422
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 5 started. Evaluating function at random point.
# [0.011207606211860571, 109, 89, 0.3266676831881398, 0.6506676052501416]
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 22.6280
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 6 started. Evaluating function at random point.
# [0.001901024531987036, 93, 60, 0.39804375112900714, 0.5104629857953324]
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 22.8524
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 7 started. Evaluating function at random point.
# [0.0371836418057321, 52, 55, 0.9840693415164489, 0.520086603923182]
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 22.3561
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 8 started. Evaluating function at random point.
# [0.05246634533625288, 8, 21, 0.47797428937106584, 0.11193846504387989]
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 22.4601
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 9 started. Evaluating function at random point.
# [0.07663082680255859, 15, 9, 0.06516793960920349, 0.30780444305993415]
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 22.4608
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 10 started. Evaluating function at random point.
# [0.003034247005811289, 61, 71, 0.6294968248934899, 0.849875420562548]
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 22.0371
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 11 started. Evaluating function at random point.
# [0.0022219245475399163, 82, 36, 0.22312428339865925, 0.7798252692858874]
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 22.4345
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 12 started. Evaluating function at random point.
# [0.007084541505250234, 55, 4, 0.22561173274925073, 0.9726261649881028]
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 22.7222
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 13 started. Evaluating function at random point.
# [0.0355030485812831, 35, 74, 0.9000859829062665, 0.6381099809299767]
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 22.0505
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 14 started. Evaluating function at random point.
# [0.06978281265126039, 73, 78, 0.23618371929818793, 0.14070456001948428]
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 22.5787
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 15 started. Evaluating function at random point.
# [0.004473636174621266, 81, 82, 0.5627075257696259, 0.6280760490974635]
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 22.2901
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 16 started. Evaluating function at random point.
# [0.0852139338138361, 61, 41, 0.3314598304188783, 0.24874024515670226]
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 22.1824
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 17 started. Evaluating function at random point.
# [0.0010746642789365084, 10, 88, 0.42513744226679123, 0.36413935724623436]
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 22.5697
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 18 started. Evaluating function at random point.
# [0.0010669882710369707, 116, 81, 0.7257748551112175, 0.8111579864780851]
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 22.1674
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 19 started. Evaluating function at random point.
# [0.016289957436723502, 107, 41, 0.9192116917665918, 0.8650347200108195]
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 22.2719
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 20 started. Evaluating function at random point.
# [0.007923213310872085, 34, 48, 0.40227733958835304, 0.7019571273972466]
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 22.7270
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 21 started. Evaluating function at random point.
# [0.02147062631022881, 45, 86, 0.8928521054475104, 0.5249934326457545]
#
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 22.1270
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 22 started. Evaluating function at random point.
# [0.0017345566642360934, 79, 3, 0.7727457961860527, 0.6051494778125467]
#
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 22.0976
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 23 started. Evaluating function at random point.
# [0.03482846706526886, 104, 27, 0.5465961879128944, 0.4847869165226947]
#
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 22.6181
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 24 started. Evaluating function at random point.
# [0.0011241862095793065, 78, 51, 0.07985772640239755, 0.6727693701374025]
#
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 22.4875
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 25 started. Evaluating function at random point.
# [0.004253162363790871, 97, 4, 0.9121881502297885, 0.3243630062339875]
#
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 22.1570
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 26 started. Evaluating function at random point.
# [0.006618595597183485, 44, 29, 0.2673582572170414, 0.1692819188459137]
#
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 22.6370
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 27 started. Evaluating function at random point.
# [0.003797544798678417, 87, 28, 0.9332127697254445, 0.8273083416079754]
#
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 22.2135
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 28 started. Evaluating function at random point.
# [0.018484491720988625, 7, 28, 0.8134884730541588, 0.2679130529974323]
#
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 22.2928
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 29 started. Evaluating function at random point.
# [0.06097025297491439, 76, 92, 0.3884829461731262, 0.9161455973911787]
#
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 23.0183
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 30 started. Evaluating function at random point.
# [0.0035015835937029, 28, 62, 0.05049435814555003, 0.4173119707007522]
#
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 22.2423
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 31 started. Evaluating function at random point.
# [0.0040697011258957775, 71, 72, 0.55738494840667, 0.536346974223085]
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 22.1116
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 32 started. Evaluating function at random point.
# [0.024258953709486806, 107, 44, 0.2819192461353855, 0.25146193795563754]
#
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 23.0187
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 33 started. Evaluating function at random point.
# [0.002738598961585681, 89, 52, 0.39544812226032927, 0.9746038744488648]
#
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 22.1612
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 34 started. Evaluating function at random point.
# [0.08411909465645724, 127, 39, 0.5223860805977663, 0.37079047883509275]
#
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 22.0874
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 35 started. Evaluating function at random point.
# [0.0037126241790405314, 82, 59, 0.6290861172809021, 0.5524111209059754]
#
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 23.2553
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 36 started. Evaluating function at random point.
# [0.00126752782698163, 102, 96, 0.9128525916683211, 0.31560570160027523]
#
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 22.2262
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 37 started. Evaluating function at random point.
# [0.0019489008462344247, 45, 90, 0.9863679314050707, 0.3178497443603504]
#
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 22.1776
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 38 started. Evaluating function at random point.
# [0.022093834415066283, 76, 56, 0.2757556667927797, 0.7553947137506737]
#
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 23.1971
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 39 started. Evaluating function at random point.
# [0.005439591236568527, 117, 98, 0.65185322522285, 0.5821972156672827]
#
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 22.4850
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 40 started. Evaluating function at random point.
# [0.0015155823539597607, 98, 73, 0.35474106172314906, 0.26786665935986886]
#
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 22.2469
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 41 started. Evaluating function at random point.
# [0.0012065637774378935, 21, 59, 0.2592289951872709, 0.7400345791942161]
#
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 22.8536
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 42 started. Evaluating function at random point.
# [0.04159126142111956, 21, 96, 0.14136772353684973, 0.9464709380406437]
#
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 22.1859
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 43 started. Evaluating function at random point.
# [0.006239417435298786, 40, 82, 0.8458246006119616, 0.7081211053353528]
#
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 22.1215
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 44 started. Evaluating function at random point.
# [0.029541479266782442, 51, 23, 0.5643755751361876, 0.7262059594105741]
#
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 23.7439
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 45 started. Evaluating function at random point.
# [0.002864837834763222, 17, 90, 0.9830599261629639, 0.5649723021439129]
#
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 22.1971
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 46 started. Evaluating function at random point.
# [0.0033239795992508463, 2, 48, 0.9671483837243541, 0.6024641082463879]
#
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 22.2542
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 47 started. Evaluating function at random point.
# [0.05824688255969174, 120, 9, 0.3149277849625728, 0.7303220469754942]
#
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 22.8736
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 48 started. Evaluating function at random point.
# [0.04935399178638847, 21, 24, 0.4342827207660806, 0.898993088884864]
#
# Iteration No: 48 ended. Evaluation done at random point.
# Time taken: 22.2111
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 49 started. Evaluating function at random point.
# [0.050333472984690764, 114, 72, 0.7960736185582465, 0.7020894292428058]
#
# Iteration No: 49 ended. Evaluation done at random point.
# Time taken: 22.2424
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 50 started. Evaluating function at random point.
# [0.014500174972770096, 113, 89, 0.6803266806526531, 0.10455542546159682]
#
# Iteration No: 50 ended. Evaluation done at random point.
# Time taken: 22.6194
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 51 started. Evaluating function at random point.
# [0.0020970853331431145, 83, 66, 0.7073004378080587, 0.6867651335523406]
#
# Iteration No: 51 ended. Evaluation done at random point.
# Time taken: 22.0854
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 52 started. Evaluating function at random point.
# [0.002808915139812626, 34, 68, 0.2753866331219601, 0.39285972834334104]
#
# Iteration No: 52 ended. Evaluation done at random point.
# Time taken: 22.3081
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 53 started. Evaluating function at random point.
# [0.031115931750282634, 9, 7, 0.7348929280395229, 0.3772547126671504]
#
# Iteration No: 53 ended. Evaluation done at random point.
# Time taken: 22.9061
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 54 started. Evaluating function at random point.
# [0.01216411342539395, 60, 86, 0.3019422492976392, 0.3195906790411752]
#
# Iteration No: 54 ended. Evaluation done at random point.
# Time taken: 22.2222
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 55 started. Evaluating function at random point.
# [0.08831228248242533, 110, 51, 0.8974442274182577, 0.6680247633975367]
#
# Iteration No: 55 ended. Evaluation done at random point.
# Time taken: 22.4220
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 56 started. Evaluating function at random point.
# [0.03887072196612057, 31, 97, 0.5980586903950412, 0.5432659244369776]
#
# Iteration No: 56 ended. Evaluation done at random point.
# Time taken: 22.3502
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 57 started. Evaluating function at random point.
# [0.0024574572727813163, 62, 48, 0.316733744318813, 0.12188436978830847]
#
# Iteration No: 57 ended. Evaluation done at random point.
# Time taken: 22.4059
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 58 started. Evaluating function at random point.
# [0.01954090133022008, 18, 44, 0.9434356551352687, 0.9585357193023287]
#
# Iteration No: 58 ended. Evaluation done at random point.
# Time taken: 22.1695
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 59 started. Evaluating function at random point.
# [0.06756608892518745, 100, 37, 0.9319026344583392, 0.485365733485583]
#
# Iteration No: 59 ended. Evaluation done at random point.
# Time taken: 22.3459
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 60 started. Evaluating function at random point.
# [0.08576491037046163, 100, 60, 0.8603589826939921, 0.36500400286262713]
#
# Iteration No: 60 ended. Evaluation done at random point.
# Time taken: 22.3705
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 61 started. Evaluating function at random point.
# [0.005891087281171031, 88, 33, 0.3510759048984638, 0.2525434720174833]
#
# Iteration No: 61 ended. Evaluation done at random point.
# Time taken: 22.4728
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 62 started. Evaluating function at random point.
# [0.012989801809330636, 96, 54, 0.7112283068412244, 0.6130550530804285]
# Iteration No: 62 ended. Evaluation done at random point.
# Time taken: 22.1813
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 63 started. Evaluating function at random point.
# [0.0015644186602631934, 33, 47, 0.9905511575990502, 0.22607561371287166]
#
# Iteration No: 63 ended. Evaluation done at random point.
# Time taken: 22.1811
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 64 started. Evaluating function at random point.
# [0.010880761845917639, 3, 90, 0.7537301868664943, 0.7273141668957412]
#
# Iteration No: 64 ended. Evaluation done at random point.
# Time taken: 22.5477
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 65 started. Evaluating function at random point.
# [0.025407864693711604, 49, 39, 0.3289122520512687, 0.8284250399306623]
#
# Iteration No: 65 ended. Evaluation done at random point.
# Time taken: 22.3693
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 66 started. Evaluating function at random point.
# [0.04170871302599375, 26, 24, 0.9175785249286479, 0.5602081589748441]
#
# Iteration No: 66 ended. Evaluation done at random point.
# Time taken: 22.3831
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 67 started. Evaluating function at random point.
# [0.010070072316456572, 46, 20, 0.667465734238877, 0.7317701895319331]
#
# Iteration No: 67 ended. Evaluation done at random point.
# Time taken: 22.5378
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 68 started. Evaluating function at random point.
# [0.03904679019183092, 77, 87, 0.07623593328001947, 0.6209784059568029]
#
# Iteration No: 68 ended. Evaluation done at random point.
# Time taken: 22.2724
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 69 started. Evaluating function at random point.
# [0.007532657932779934, 64, 86, 0.36174503410099534, 0.2395374550549698]
#
# Iteration No: 69 ended. Evaluation done at random point.
# Time taken: 22.2450
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 70 started. Evaluating function at random point.
# [0.09197753718752462, 23, 58, 0.8673843873960916, 0.3252262244642777]
#
# Iteration No: 70 ended. Evaluation done at random point.
# Time taken: 23.2463
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 71 started. Evaluating function at random point.
# [0.0011958300672269895, 16, 54, 0.5602283058368227, 0.39398611761643687]
#
# Iteration No: 71 ended. Evaluation done at random point.
# Time taken: 22.2713
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 72 started. Evaluating function at random point.
# [0.04526244473698836, 61, 5, 0.48440190353304213, 0.8578207675107833]
#
# Iteration No: 72 ended. Evaluation done at random point.
# Time taken: 22.2959
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 73 started. Evaluating function at random point.
# [0.0024477105965661594, 95, 47, 0.7145366002288343, 0.22451778317602125]
#
# Iteration No: 73 ended. Evaluation done at random point.
# Time taken: 23.0888
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 74 started. Evaluating function at random point.
# [0.0018428536387181335, 115, 30, 0.08901414092948201, 0.4589388113003151]
#
# Iteration No: 74 ended. Evaluation done at random point.
# Time taken: 22.0966
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 75 started. Evaluating function at random point.
# [0.007362774086950573, 59, 55, 0.2883175009793282, 0.2659003068982331]
#
# Iteration No: 75 ended. Evaluation done at random point.
# Time taken: 22.2216
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 76 started. Evaluating function at random point.
# [0.0014512623657010908, 128, 9, 0.7040749057270982, 0.15237423595759925]
#
# Iteration No: 76 ended. Evaluation done at random point.
# Time taken: 23.6774
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 77 started. Evaluating function at random point.
# [0.06767487390617134, 112, 34, 0.2777979911995331, 0.1844859610731626]
#
# Iteration No: 77 ended. Evaluation done at random point.
# Time taken: 22.3788
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 78 started. Evaluating function at random point.
# [0.0023213038634316936, 110, 1, 0.9571220166300345, 0.7641072250261918]
#
# Iteration No: 78 ended. Evaluation done at random point.
# Time taken: 22.3475
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 79 started. Evaluating function at random point.
# [0.012844230922809454, 23, 93, 0.4486200593064004, 0.32295789055104174]
#
# Iteration No: 79 ended. Evaluation done at random point.
# Time taken: 23.2568
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 80 started. Evaluating function at random point.
# [0.005151638228695851, 102, 86, 0.06367381419826808, 0.20446537645622465]
#
# Iteration No: 80 ended. Evaluation done at random point.
# Time taken: 22.7760
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 81 started. Evaluating function at random point.
# [0.0012359624712587382, 114, 94, 0.862687554810457, 0.7332920734420214]
#
# Iteration No: 81 ended. Evaluation done at random point.
# Time taken: 22.3280
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 82 started. Evaluating function at random point.
# [0.008878664758716853, 91, 90, 0.5170350813609907, 0.5261245937025092]
#
# Iteration No: 82 ended. Evaluation done at random point.
# Time taken: 23.3831
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 83 started. Evaluating function at random point.
# [0.0022202595144810546, 95, 23, 0.09565597798718205, 0.9542311584322475]
#
# Iteration No: 83 ended. Evaluation done at random point.
# Time taken: 22.3131
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 84 started. Evaluating function at random point.
# [0.05934180807121823, 53, 95, 0.06453931327586551, 0.9400926772715348]
#
# Iteration No: 84 ended. Evaluation done at random point.
# Time taken: 22.7784
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 85 started. Evaluating function at random point.
# [0.010048003272349209, 121, 69, 0.6997655809282342, 0.6542660479509225]
#
# Iteration No: 85 ended. Evaluation done at random point.
# Time taken: 23.1902
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 86 started. Evaluating function at random point.
# [0.07722949750823004, 3, 92, 0.6064868022097902, 0.9462072172824619]
#
# Iteration No: 86 ended. Evaluation done at random point.
# Time taken: 23.1181
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 87 started. Evaluating function at random point.
# [0.014156254304586417, 51, 35, 0.6611238075202356, 0.512427601442365]
#
# Iteration No: 87 ended. Evaluation done at random point.
# Time taken: 22.2793
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 88 started. Evaluating function at random point.
# [0.012337682181468138, 102, 12, 0.41679750591073556, 0.9650715074415229]
#
# Iteration No: 88 ended. Evaluation done at random point.
# Time taken: 22.9769
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 89 started. Evaluating function at random point.
# [0.0646697651670196, 45, 29, 0.11589323583140719, 0.190700201239684]
#
# Iteration No: 89 ended. Evaluation done at random point.
# Time taken: 22.0336
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 90 started. Evaluating function at random point.
# [0.0010875360232120634, 116, 35, 0.3697265041442902, 0.690150371842668]
#
# Iteration No: 90 ended. Evaluation done at random point.
# Time taken: 22.1436
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 91 started. Evaluating function at random point.
# [0.005899201652681352, 75, 90, 0.37359334099102803, 0.33462507541231284]
#
# Iteration No: 91 ended. Evaluation done at random point.
# Time taken: 22.9404
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 92 started. Evaluating function at random point.
# [0.00981917292843153, 59, 75, 0.8835984128507004, 0.7615639394234973]
#
# Iteration No: 92 ended. Evaluation done at random point.
# Time taken: 22.1649
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 93 started. Evaluating function at random point.
# [0.04045403638787864, 122, 36, 0.21856756659073667, 0.7755532764767726]
# Iteration No: 93 ended. Evaluation done at random point.
# Time taken: 22.2349
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 94 started. Evaluating function at random point.
# [0.04108369330865427, 50, 99, 0.44198679306585514, 0.4348162772135049]
#
# Iteration No: 94 ended. Evaluation done at random point.
# Time taken: 22.7753
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 95 started. Evaluating function at random point.
# [0.03571296609641059, 25, 23, 0.9342194593233866, 0.8725714766587107]
#
# Iteration No: 95 ended. Evaluation done at random point.
# Time taken: 22.1143
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 96 started. Evaluating function at random point.
# [0.007210876454272621, 14, 23, 0.7668157303804484, 0.19281148195233938]
#
# Iteration No: 96 ended. Evaluation done at random point.
# Time taken: 22.2073
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 97 started. Evaluating function at random point.
# [0.063841901437349, 63, 84, 0.8351345928023547, 0.38804464092755064]
#
# Iteration No: 97 ended. Evaluation done at random point.
# Time taken: 22.7308
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 98 started. Evaluating function at random point.
# [0.061808251361692164, 50, 100, 0.060295768906283444, 0.9148437787773374]
#
# Iteration No: 98 ended. Evaluation done at random point.
# Time taken: 22.2596
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 99 started. Evaluating function at random point.
# [0.0015225562752457951, 72, 28, 0.9525588686982648, 0.9555464322438006]
#
# Iteration No: 99 ended. Evaluation done at random point.
# Time taken: 22.7753
# Function value obtained: -0.8487
# Current minimum: -0.8487
# Iteration No: 100 started. Evaluating function at random point.
# [0.01402412507055007, 112, 16, 0.4760232458794038, 0.36388969452825815]
#
# Iteration No: 100 ended. Evaluation done at random point.
# Time taken: 23.9430
# Function value obtained: -0.8487
# Current minimum: -0.8487

# %%
resultado.x
# Out:
# [0.03918194347141743, 16, 72, 0.6187255599871848, 0.2404167763981929]

# %% [markdown]
# # Model  LGB

# %%
lgbm_params_rs = {
    "objective": "binary",
    "learning_rate": resultado.x[0],
    'n_estimators': 1200,
    'num_leaves': resultado.x[1],
    'min_child_samples': resultado.x[2],
    'subsample':resultado.x[3],
    'colsample_bytree': resultado.x[3]
}

# %%
model = LGBMClassifier(**lgbm_params_rs)
model
# Out:
# LGBMClassifier(colsample_bytree=0.6187255599871848,
#                learning_rate=0.03918194347141743, min_child_samples=72,
#                n_estimators=1000, num_leaves=16, objective='binary',
#                subsample=0.6187255599871848)

# %% [markdown]
# ## Cross Validate

# %%
splits = 10
skf = StratifiedKFold(n_splits=splits, shuffle=True, random_state=42)

oof_preds = np.zeros((X.shape[0],))
preds = 0
model_fi = 0
total_mean_auc = 0

for num, (train_idx, valid_idx) in enumerate(skf.split(X, y)):
    X_train, X_valid = X.loc[train_idx], X.loc[valid_idx]
    y_train, y_valid = y.loc[train_idx], y.loc[valid_idx]
    
    imputer = SimpleImputer(strategy='median')
    X_train = imputer.fit_transform(X_train)
    X_valid = imputer.transform(X_valid)
    
    model.fit(X_train, y_train,
              verbose=False,
              eval_set=[(X_train, y_train), (X_valid, y_valid)],
              eval_metric="auc",
              early_stopping_rounds=200,
              )
    
    X_test = imputer.transform(X_test)
    
    preds += model.predict_proba(X_test)[:, 1] / splits
   
   
    
    model_fi += model.feature_importances_ / splits
    
    oof_preds[valid_idx] = model.predict_proba(X_valid)[:, 1]
    
    fold_auc = roc_auc_score(y_valid, oof_preds[valid_idx])
    print(f"Fold {num} ROC AUC: {fold_auc}")

    total_mean_auc += fold_auc / splits
    
print(f"\nOverall ROC AUC: {total_mean_auc}")
# Out:
# Fold 0 ROC AUC: 0.8576343457481559
# Fold 1 ROC AUC: 0.8543535826612859
# Fold 2 ROC AUC: 0.8562044869028016
# Fold 3 ROC AUC: 0.8550051130743109
# Fold 4 ROC AUC: 0.8556868097157193
#
# Overall ROC AUC: 0.8557768676204548

# %%
lgbmscore = total_mean_auc
lgbmscore
# Out:
# 0.8557768676204548

# %% [markdown]
# #### Submission

# %%
submission.target = preds
submission.head()
# Out:
#         id    target
# 0  1000000  0.749457
# 1  1000001  0.279005
# 2  1000002  0.892444
# 3  1000003  0.832792
# 4  1000004  0.262579

# %% [markdown]
# ## Submission

# %%
#submission = pd.read_csv("sample_solution.csv")
#submission.target = preds
submission.to_csv('submissionlgb.csv', index=False)
